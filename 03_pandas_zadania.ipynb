# %% [markdown]
# ## PANDAS wprowadzenie

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %%
# Tworzenie Dataframe ze słownika
'''
{'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
'''

df = ...
print(df)

# %%
# Tworzenie Dataframe z podanymi indeksami
'''
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
'''

df_2 = ...
print(df_2)

# %%
# wyświetl 3 pierwsze wiersze ramki df_2

# %%
# z ramki df_2 wyświetl jakie ma kolumny, a następnie wyświetl tylko kolumny score i qualify

# %%
# wyświetl wiersze tak gdzie było więcej niż 2 attempts

# %%
# wierszu d zmień score na 11.5 -> metoda .loc

# %%
# wyświetl sumę attempts

# %%
# posortuj wartości po name, a następnie score, name rosnąco a score malejąco

# %%
# usuń wiersze z wartościami nan, czy aby napewno wynik się zapisał?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Na podstawie poniżeszego Dataframe pogrupuj uczniów wg szkoły (school_code)

student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

groups = ...

for name,group in groups:
    print("\nGroup:")
    print(name)
    print(group)

# %%
# dla każdej szkoły podaj średni wiek, oraz min i max wiek

# %%
# zamień imiona i nazwiska studentów na wielkie litery

# %%
# zmień nazwę kolumny address na street_name

# %% [markdown]
# ## PANDAS ćwiczenia na zajęciach

# %% [markdown]
# Z podanego słownika uwórz ramkę danych DataFrame

# %%
my_dict = {
    'product' : ['avocado', 'bread', 'bun', 'tomato', 'potatoes', 'milk'],
    'price' : [2, 5, 7.0, 8, 12, 3.5],
    'department' : ['veggies', 'bakery', 'bakery', 'veggies', 'veggies', 'fridge']
}

# %% [markdown]
# Wyświetl 2 pierwsze wiersze z ramki.

# %% [markdown]
# Z uwagi na inflację podnieś ceny produktów o 19%.

# %% [markdown]
# Czy napewno udało się zapisać zmiany w ramce?

# %% [markdown]
# Wyświetl wszystkie produkty sprzedawane w piekarni.

# %% [markdown]
# Spróbuj wyświetlić wszystkie produkty, które nie są sprzedawane w piekarni.

# %% [markdown]
# Dla każdej sekcji (piekarnia, warzywa, produkty z lodówki) wyświetl średnią cenę. Skorzystaj z agregacji.

# %% [markdown]
# Zmień nazwy kolumn na inne w języku polskim.

# %% [markdown]
# ## Praca domowa (16 pkt)

# %% [markdown]
# Wgraj dane z pliku DANE_PAD_O3.csv jako ramkę danych.
#
# Oblicz liczebność każdej wartości w kolumnie COUNTRY.

# %% [markdown]
# W nowej kolumnie ‘owned_goods’ dodaj zmienną, która będzie informowała o liczbie posiadanych dóbr (zliczyć ile dana osoba posiada w sumie dóbr).

# %% [markdown]
# Porównaj średnią posiadanych dóbr między kobietami i mężczyznami. Wynik zaokrąglij do 2 miejsc po przecinku.

# %% [markdown]
# Stwórz ramkę danych, która zawierać będzie w pierwszej kolumnie wartość zmiennej COUNTRY, w drugiej kolumnie, średnią posiadanych dóbr w danym kraju (Wynik zaokrąglij do 2 miejsc po przecink), a w trzeciej kolumnie minimum wieku.
